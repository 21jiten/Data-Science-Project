# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Test.csv", encoding='latin1')
print(df.info())
df.columns = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9']
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4815 entries, 0 to 4814
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   textID            3534 non-null   object
#  1   text              3534 non-null   object
#  2   sentiment         3534 non-null   object
#  3   Time of Tweet     3534 non-null   object
#  4   Age of User       3534 non-null   object
#  5   Country           3534 non-null   object
#  6   Population -2020  3534 non-null   float64
#  7   Land Area (Km²)   3534 non-null   float64
#  8   Density (P/Km²)   3534 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 338.7+ KB
# None

# %%
df.describe()
# Out:
#                col7          col8          col9
# count  3.534000e+03  3.534000e+03   3534.000000
# mean   3.941891e+07  6.722499e+05    348.894171
# std    1.468757e+08  1.839134e+06   1967.012367
# min    8.010000e+02  0.000000e+00      2.000000
# 25%    1.968001e+06  2.281000e+04     35.000000
# 50%    8.696453e+06  1.127600e+05     87.000000
# 75%    2.843594e+07  5.279700e+05    214.000000
# max    1.439324e+09  1.637687e+07  26337.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4815 entries, 0 to 4814
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    3534 non-null   object
#  1   col2    3534 non-null   object
#  2   col3    3534 non-null   object
#  3   col4    3534 non-null   object
#  4   col5    3534 non-null   object
#  5   col6    3534 non-null   object
#  6   col7    3534 non-null   float64
#  7   col8    3534 non-null   float64
#  8   col9    3534 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 338.7+ KB

# %%
df.columns
# Out:
# Index(['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9'], dtype='object')

# %%
print(df.shape)
df.head(10).T
# Out:
# (4815, 9)
#                                                       0  \
# col1                                         f87dea47db
# col2  Last session of the day  http://twitpic.com/67ezh
# col3                                            neutral
# col4                                            morning
# col5                                               0-20
# col6                                        Afghanistan
# col7                                         38928346.0
# col8                                           652860.0
# col9                                               60.0
#
#                                                       1  \
# col1                                         96d74cb729
# col2   Shanghai is also really exciting (precisely -...
# col3                                           positive
# col4                                               noon
# col5                                              21-30
# ...

# %%
df.isnull().sum()
# Out:
# col1    1281
# col2    1281
# col3    1281
# col4    1281
# col5    1281
# col6    1281
# col7    1281
# col8    1281
# col9    1281
# dtype: int64

# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
nltk.download('stopwords')
nltk.download('punkt')

df = pd.read_csv("Test.csv", encoding='latin1')
print(df.info())
df.columns = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9']

def preprocess_text(text):
   
    text = text.lower()
    
    
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    
    tokens = word_tokenize(text)
    

    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
 
    processed_text = ' '.join(tokens)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4815 entries, 0 to 4814
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   textID            3534 non-null   object
#  1   text              3534 non-null   object
#  2   sentiment         3534 non-null   object
#  3   Time of Tweet     3534 non-null   object
#  4   Age of User       3534 non-null   object
#  5   Country           3534 non-null   object
#  6   Population -2020  3534 non-null   float64
#  7   Land Area (Km²)   3534 non-null   float64
#  8   Density (P/Km²)   3534 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 338.7+ KB
# None
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("Test.csv", encoding='latin1')
print(df.info())
df.columns = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9']


print(df.info())


sns.countplot(x='col9', data=df)
plt.title('Distribution of Sentiment Classes')
plt.xlabel('Sentiment Class')
plt.ylabel('Count')
plt.show()


numeric_cols = df.select_dtypes(include=['float64', 'int64']).columns
sns.pairplot(df[numeric_cols])
plt.suptitle('Pair Plot of Numeric Columns', y=1.02)
plt.show()


correlation_matrix = df[numeric_cols].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4815 entries, 0 to 4814
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   textID            3534 non-null   object
#  1   text              3534 non-null   object
#  2   sentiment         3534 non-null   object
#  3   Time of Tweet     3534 non-null   object
#  4   Age of User       3534 non-null   object
#  5   Country           3534 non-null   object
#  6   Population -2020  3534 non-null   float64
#  7   Land Area (Km²)   3534 non-null   float64
#  8   Density (P/Km²)   3534 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 338.7+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4815 entries, 0 to 4814
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col1    3534 non-null   object
#  1   col2    3534 non-null   object
# ...

# %%
nltk.download('vader_lexicon')
from nltk.sentiment import SentimentIntensityAnalyzer



sia = SentimentIntensityAnalyzer()


df['AFINN_Score'] = df['col1'].apply(lambda x: sia.polarity_scores(x)['compound'] if pd.notna(x) else 0)


plt.figure(figsize=(10, 6))
sns.boxplot(x='col9', y='AFINN_Score', data=df)
plt.title('Box Plot of AFINN Scores by Sentiment Class')
plt.xlabel('Sentiment Class')
plt.ylabel('AFINN Score')
plt.show()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# C:\Users\jiten\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Test.csv", encoding='latin1')
print(df.info())
df.columns = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9']



sentiment_distribution = df['col9'].value_counts()


plt.figure(figsize=(8, 8))
plt.pie(sentiment_distribution, labels=sentiment_distribution.index, autopct='%1.1f%%', startangle=90, colors=['#66b3ff','#99ff99','#ff9999'])
plt.title('Distribution of Sentiment Classes')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4815 entries, 0 to 4814
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   textID            3534 non-null   object
#  1   text              3534 non-null   object
#  2   sentiment         3534 non-null   object
#  3   Time of Tweet     3534 non-null   object
#  4   Age of User       3534 non-null   object
#  5   Country           3534 non-null   object
#  6   Population -2020  3534 non-null   float64
#  7   Land Area (Km²)   3534 non-null   float64
#  8   Density (P/Km²)   3534 non-null   float64
# dtypes: float64(3), object(6)
# memory usage: 338.7+ KB
# None

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string


nltk.download('stopwords')
nltk.download('punkt')


df = pd.read_csv("Test.csv", encoding='latin1')
df.columns = ['col1', 'col2', 'col3', 'col4', 'col5', 'col6', 'col7', 'col8', 'col9']


def preprocess_text(text):
    
    if pd.isna(text):
        return ""
    
   
    text = text.lower()
    
    
    text = text.translate(str.maketrans('', '', string.punctuation))
    
    
    tokens = word_tokenize(text)
    
    
    stop_words = set(stopwords.words('english'))
    tokens = [token for token in tokens if token not in stop_words]
    
    
    processed_text = ' '.join(tokens)
    return processed_text


df['Processed_Text'] = df['col1'].apply(preprocess_text)


tfidf_vectorizer = TfidfVectorizer(max_features=5000, stop_words='english')
X_tfidf = tfidf_vectorizer.fit_transform(df['Processed_Text'])


df_tfidf = pd.DataFrame(X_tfidf.toarray(), columns=tfidf_vectorizer.get_feature_names_out())


y = df['col9']


label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)


X_train, X_test, y_train, y_test = train_test_split(df_tfidf, y_encoded, test_size=0.2, random_state=42)


nb_model = MultinomialNB()
nb_model.fit(X_train, y_train)
nb_predictions = nb_model.predict(X_test)


svm_model = SVC()
svm_model.fit(X_train, y_train)
svm_predictions = svm_model.predict(X_test)


def evaluate_model(predictions, true_labels):
    accuracy = accuracy_score(true_labels, predictions)
    precision = precision_score(true_labels, predictions, average='weighted')
    recall = recall_score(true_labels, predictions, average='weighted')
    f1 = f1_score(true_labels, predictions, average='weighted')
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall: {recall:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print("\nClassification Report:")
    print(classification_report(true_labels, predictions, target_names=label_encoder.classes_))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jiten\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from sklearn.metrics import classification_report

print("Naive Bayes Model Evaluation:")
print(classification_report(y_test, nb_predictions, labels=label_encoder.transform(label_encoder.classes_).astype(int), target_names=label_encoder.classes_.astype(str), zero_division=1))


print("\nSupport Vector Machines (SVM) Evaluation:")
print(classification_report(y_test, svm_predictions, labels=label_encoder.transform(label_encoder.classes_).astype(int), target_names=label_encoder.classes_.astype(str), zero_division=1))
# Out:
# Naive Bayes Model Evaluation:
#               precision    recall  f1-score   support
#
#          2.0       1.00      0.00      0.00         2
#          3.0       1.00      0.00      0.00        10
#          4.0       1.00      0.00      0.00        20
#          5.0       1.00      0.00      0.00         2
#          7.0       1.00      0.00      0.00         2
#          8.0       1.00      0.00      0.00         3
#          9.0       1.00      0.00      0.00        10
#         11.0       1.00      0.00      0.00         6
#         13.0       1.00      0.00      0.00         6
#         15.0       1.00      1.00      1.00         0
#         16.0       1.00      0.00      0.00        11
#         17.0       1.00      0.00      0.00         9
#         18.0       1.00      0.00      0.00        15
#         19.0       1.00      0.00      0.00         3
#         20.0       1.00      0.00      0.00        12
#         25.0       1.00      0.00      0.00        13
# ...

# %%
from sklearn.model_selection import GridSearchCV


param_grid = {
    'alpha': [0.1, 0.5, 1.0],
    'fit_prior': [True, False]
}


grid_search = GridSearchCV(estimator=nb_model, param_grid=param_grid, scoring='accuracy', cv=5)


grid_search.fit(X_train, y_train)


best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)


best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)


print("Classification Report:")
print(classification_report(y_test, y_pred, labels=label_encoder.transform(label_encoder.classes_).astype(int), target_names=label_encoder.classes_.astype(str), zero_division=1))
# Out:
# Best Hyperparameters: {'alpha': 0.1, 'fit_prior': True}
# Classification Report:
#               precision    recall  f1-score   support
#
#          2.0       1.00      0.00      0.00         2
#          3.0       1.00      0.00      0.00        10
#          4.0       1.00      0.00      0.00        20
#          5.0       1.00      0.00      0.00         2
#          7.0       1.00      0.00      0.00         2
#          8.0       1.00      0.00      0.00         3
#          9.0       1.00      0.00      0.00        10
#         11.0       1.00      0.00      0.00         6
#         13.0       1.00      0.00      0.00         6
#         15.0       1.00      1.00      1.00         0
#         16.0       1.00      0.00      0.00        11
#         17.0       1.00      0.00      0.00         9
#         18.0       1.00      0.00      0.00        15
#         19.0       1.00      0.00      0.00         3
#         20.0       1.00      0.00      0.00        12
# ...

# %%
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.metrics import make_scorer
from sklearn.naive_bayes import MultinomialNB
import numpy as np  # Import NumPy




nb_model = MultinomialNB()


cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)


scorer = make_scorer(accuracy_score) 


cv_scores = cross_val_score(nb_model, X_train, y_train, cv=cv_strategy, scoring=scorer)


print("Cross-Validation Scores:", cv_scores)


print("Average Cross-Validation Score:", np.mean(cv_scores))
print("Standard Deviation of Cross-Validation Scores:", np.std(cv_scores))
# Out:
# Cross-Validation Scores: [0.26588846 0.26588846 0.26623377 0.26493506 0.26493506]
# Average Cross-Validation Score: 0.2655761618407532
# Standard Deviation of Cross-Validation Scores: 0.0005384254810913542
